# %% [markdown]
# # Chapter 11: Path Tracing Implementation
#
# This notebook covers the implementation topics from Chapter 11.
#
# See README.md for detailed topics and key references.

# %%
# Your implementation starts here
